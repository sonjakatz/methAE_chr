# %%
import pandas as pd
import numpy as np
import pickle 
import torch
from data.prepareData import prepareDataLoader_fromPkl
import matplotlib.pyplot as plt

# %% [markdown]
# # Train models with different latent space sizes
#
# Training parameters:
#
# Setups tried:
#
# `latentSize = 25`

# %%
# !python train_AE.py --name smoking_chr5/latSize_25 \
                    --train_file chr5_smoking_train.pkl \
                    --val_file chr5_smoking_val.pkl \
                    --hidden_layer_encoder_topology 5000 500 \
                    --latentSize 25 \
                    --learning_rate 1e-04 \
                    --n_epochs 500 \
                    --patienceEarlyStopping 300
# Out:
# normalAE(
#   (encoder): Sequential(
#     (0): Linear(in_features=24247, out_features=5000, bias=True)
#     (1): Dropout(p=0.3, inplace=False)
#     (2): PReLU(num_parameters=1)
#     (3): BatchNorm1d(5000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): Linear(in_features=5000, out_features=500, bias=True)
#     (5): Dropout(p=0.3, inplace=False)
#     (6): PReLU(num_parameters=1)
#     (7): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): Linear(in_features=500, out_features=25, bias=True)
#     (9): PReLU(num_parameters=1)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=25, out_features=500, bias=True)
#     (1): PReLU(num_parameters=1)
#     (2): Linear(in_features=500, out_features=5000, bias=True)
#     (3): PReLU(num_parameters=1)
#     (4): Linear(in_features=5000, out_features=24247, bias=True)
#     (5): Sigmoid()
#   )
# )
# 		Logging to logs/smoking_chr5/latSize_25/checkpoint
# cpu
# ...
